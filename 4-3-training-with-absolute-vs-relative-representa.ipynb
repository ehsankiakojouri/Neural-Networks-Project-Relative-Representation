# %%
from torchvision import models
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn, optim
from torchvision.models import resnet18
import torch.nn.functional as F
from pytorch_lightning import seed_everything
import random
from sklearn.metrics import classification_report

num_anchors = 300
hidden_features = 512
seed_everything(1)
one_dimentional_data = False

# Step 1: Define the transformations for the training and test sets
transform = transforms.Compose([
    transforms.Grayscale(3) if one_dimentional_data else transforms.Lambda(lambda x: x),
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# Step 2: Load CIFAR-10 dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Step 3: select and partition anchors
def get_anchors_idx(num_anchors: int, max_anchors_len: int):
    assert num_anchors <= max_anchors_len
    anchor_idxs = list(range(max_anchors_len))
    random.shuffle(anchor_idxs)
    anchor_idxs = anchor_idxs[:num_anchors]
    return anchor_idxs

anchors_idx = get_anchors_idx(num_anchors, max_anchors_len=len(trainset))
# Extract subset of training dataset using the list of indices
anchors_set = torch.utils.data.Subset(trainset, anchors_idx)
anchorloader = torch.utils.data.DataLoader(anchors_set, batch_size=num_anchors, shuffle=False, num_workers=2)

class RelRepBlock(nn.Module):
    def __init__(self, normalization, num_anchors):
        super(RelRepBlock, self).__init__()
        self.num_anchors = num_anchors
        self.normalization = normalization
        if normalization:
            self.outnorm = nn.LayerNorm(normalized_shape=num_anchors)

    def forward(self, x: torch.Tensor, anchors: torch.Tensor) -> torch.Tensor:
        x = F.normalize(x, p=2, dim=-1)
        anchors = F.normalize(anchors, p=2, dim=-1)
        relative_reps = torch.einsum("nd, ad -> na", x, anchors)

        if self.normalization:
            return self.outnorm(relative_reps)
        else:
            return relative_reps

# Step 4: Initialize ResNet-18 model and modify it
class RelativeResNet18(nn.Module):
    def __init__(self, num_anchors, hidden_features, fine_tune=False):
        super(RelativeResNet18, self).__init__()
        # Remove the last fully connected layer
        self.resnet = resnet18(pretrained=True)
        self.resnet18_fc_shape = self.resnet.fc.in_features
        self.resnet.fc = nn.Identity()
        
        if not fine_tune:
            for param in self.resnet.parameters():
                param.requires_grad = False
                param.grad = None
            
        self.post_resnet_nn = nn.Sequential(
            nn.Linear(in_features=self.resnet18_fc_shape, out_features=self.resnet18_fc_shape),
            nn.BatchNorm1d(num_features=self.resnet18_fc_shape),
            nn.Tanh(),
            nn.Linear(in_features=self.resnet18_fc_shape, out_features=hidden_features),
            nn.Tanh(),
        )
        # Relative Representation Transform
        self.relative_transform = RelRepBlock(normalization=True, num_anchors=num_anchors)
        self.output_layer = nn.Linear(num_anchors, 10)

    def forward(self, x, anchors):
        with torch.no_grad():
            anchors_latents = self.resnet(anchors)
            anchors_latents = self.post_resnet_nn(anchors_latents)
            x_latents = self.resnet(x)
        x_latents = self.post_resnet_nn(x_latents)
        relative_reps = self.relative_transform(x_latents, anchors_latents)
        return self.output_layer(relative_reps)


# Initialize the modified model
model = RelativeResNet18(hidden_features=hidden_features, num_anchors=num_anchors)

# If using a GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Step 5: Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Step 6: Train the model
def train(epoch):
    model.train()
    running_loss = 0.0
    anchors, _ = next(iter(anchorloader))
    anchors = anchors.to(device)
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs, anchors)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i % 100 == 99:    # print every 100 mini-batches
            print(f'[Epoch {epoch + 1}, Batch {i + 1}] loss: {running_loss / 100:.3f}')
            running_loss = 0.0

# Step 7: Evaluate the model
def test():
    model.eval()
    all_labels = []
    all_predictions = []
    anchors, _ = next(iter(anchorloader))
    anchors = anchors.to(device)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = model(images, anchors)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    print(classification_report(all_labels, all_predictions))

# Training and Testing Loop
for epoch in range(10):  # number of epochs
    train(epoch)
    test()

print('Finished Training')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:02<00:00, 80393027.56it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 141MB/s]
# [Epoch 1, Batch 100] loss: 1.122
# [Epoch 1, Batch 200] loss: 0.804
# [Epoch 1, Batch 300] loss: 0.775
# [Epoch 1, Batch 400] loss: 0.757
# [Epoch 1, Batch 500] loss: 0.760
# [Epoch 1, Batch 600] loss: 0.702
# [Epoch 1, Batch 700] loss: 0.697
# [Epoch 1, Batch 800] loss: 0.696
# [Epoch 1, Batch 900] loss: 0.689
# [Epoch 1, Batch 1000] loss: 0.702
# [Epoch 1, Batch 1100] loss: 0.712
# [Epoch 1, Batch 1200] loss: 0.660
# [Epoch 1, Batch 1300] loss: 0.684
# [Epoch 1, Batch 1400] loss: 0.672
# [Epoch 1, Batch 1500] loss: 0.675
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80      1000
#            1       0.88      0.87      0.87      1000
#            2       0.71      0.74      0.72      1000
#            3       0.75      0.51      0.61      1000
#            4       0.76      0.75      0.75      1000
#            5       0.68      0.81      0.74      1000
#            6       0.76      0.88      0.81      1000
#            7       0.86      0.77      0.82      1000
#            8       0.81      0.88      0.84      1000
#            9       0.88      0.82      0.85      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.79      0.78      0.78     10000
# weighted avg       0.79      0.78      0.78     10000
#
# [Epoch 2, Batch 100] loss: 0.642
# [Epoch 2, Batch 200] loss: 0.618
# [Epoch 2, Batch 300] loss: 0.645
# [Epoch 2, Batch 400] loss: 0.625
# [Epoch 2, Batch 500] loss: 0.642
# [Epoch 2, Batch 600] loss: 0.659
# [Epoch 2, Batch 700] loss: 0.663
# [Epoch 2, Batch 800] loss: 0.647
# [Epoch 2, Batch 900] loss: 0.661
# [Epoch 2, Batch 1000] loss: 0.639
# [Epoch 2, Batch 1100] loss: 0.635
# [Epoch 2, Batch 1200] loss: 0.652
# [Epoch 2, Batch 1300] loss: 0.623
# [Epoch 2, Batch 1400] loss: 0.613
# [Epoch 2, Batch 1500] loss: 0.635
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81      1000
#            1       0.80      0.94      0.86      1000
#            2       0.80      0.71      0.75      1000
#            3       0.68      0.67      0.67      1000
#            4       0.77      0.73      0.75      1000
#            5       0.73      0.77      0.75      1000
#            6       0.84      0.82      0.83      1000
#            7       0.76      0.85      0.80      1000
#            8       0.89      0.82      0.85      1000
#            9       0.91      0.81      0.85      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.80      0.79      0.79     10000
# weighted avg       0.80      0.79      0.79     10000
#
# [Epoch 3, Batch 100] loss: 0.610
# [Epoch 3, Batch 200] loss: 0.571
# [Epoch 3, Batch 300] loss: 0.605
# [Epoch 3, Batch 400] loss: 0.600
# [Epoch 3, Batch 500] loss: 0.591
# [Epoch 3, Batch 600] loss: 0.612
# [Epoch 3, Batch 700] loss: 0.608
# [Epoch 3, Batch 800] loss: 0.602
# [Epoch 3, Batch 900] loss: 0.605
# [Epoch 3, Batch 1000] loss: 0.615
# [Epoch 3, Batch 1100] loss: 0.610
# [Epoch 3, Batch 1200] loss: 0.607
# [Epoch 3, Batch 1300] loss: 0.600
# [Epoch 3, Batch 1400] loss: 0.607
# [Epoch 3, Batch 1500] loss: 0.624
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      1000
#            1       0.88      0.88      0.88      1000
#            2       0.79      0.74      0.77      1000
#            3       0.67      0.67      0.67      1000
#            4       0.78      0.75      0.77      1000
#            5       0.73      0.78      0.76      1000
#            6       0.83      0.84      0.83      1000
#            7       0.84      0.79      0.81      1000
#            8       0.89      0.82      0.86      1000
#            9       0.81      0.90      0.85      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.80      0.80     10000
#
# [Epoch 4, Batch 100] loss: 0.566
# [Epoch 4, Batch 200] loss: 0.565
# [Epoch 4, Batch 300] loss: 0.607
# [Epoch 4, Batch 400] loss: 0.599
# [Epoch 4, Batch 500] loss: 0.556
# [Epoch 4, Batch 600] loss: 0.580
# [Epoch 4, Batch 700] loss: 0.597
# [Epoch 4, Batch 800] loss: 0.589
# [Epoch 4, Batch 900] loss: 0.566
# [Epoch 4, Batch 1000] loss: 0.600
# [Epoch 4, Batch 1100] loss: 0.593
# [Epoch 4, Batch 1200] loss: 0.580
# [Epoch 4, Batch 1300] loss: 0.563
# [Epoch 4, Batch 1400] loss: 0.582
# [Epoch 4, Batch 1500] loss: 0.594
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83      1000
#            1       0.88      0.89      0.89      1000
#            2       0.82      0.72      0.77      1000
#            3       0.62      0.76      0.68      1000
#            4       0.78      0.74      0.76      1000
#            5       0.80      0.69      0.74      1000
#            6       0.86      0.80      0.83      1000
#            7       0.75      0.87      0.80      1000
#            8       0.88      0.87      0.88      1000
#            9       0.87      0.87      0.87      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.81      0.80      0.80     10000
# weighted avg       0.81      0.80      0.80     10000
#
# [Epoch 5, Batch 100] loss: 0.579
# [Epoch 5, Batch 200] loss: 0.535
# [Epoch 5, Batch 300] loss: 0.548
# [Epoch 5, Batch 400] loss: 0.552
# [Epoch 5, Batch 500] loss: 0.561
# [Epoch 5, Batch 600] loss: 0.566
# [Epoch 5, Batch 700] loss: 0.560
# [Epoch 5, Batch 800] loss: 0.525
# [Epoch 5, Batch 900] loss: 0.542
# [Epoch 5, Batch 1000] loss: 0.573
# [Epoch 5, Batch 1100] loss: 0.552
# [Epoch 5, Batch 1200] loss: 0.564
# [Epoch 5, Batch 1300] loss: 0.571
# [Epoch 5, Batch 1400] loss: 0.558
# [Epoch 5, Batch 1500] loss: 0.570
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      1000
#            1       0.92      0.82      0.87      1000
#            2       0.83      0.73      0.78      1000
#            3       0.62      0.78      0.69      1000
#            4       0.77      0.78      0.77      1000
#            5       0.76      0.76      0.76      1000
#            6       0.86      0.83      0.85      1000
#            7       0.91      0.75      0.82      1000
#            8       0.86      0.89      0.87      1000
#            9       0.82      0.90      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 6, Batch 100] loss: 0.530
# [Epoch 6, Batch 200] loss: 0.510
# [Epoch 6, Batch 300] loss: 0.533
# [Epoch 6, Batch 400] loss: 0.502
# [Epoch 6, Batch 500] loss: 0.533
# [Epoch 6, Batch 600] loss: 0.524
# [Epoch 6, Batch 700] loss: 0.527
# [Epoch 6, Batch 800] loss: 0.511
# [Epoch 6, Batch 900] loss: 0.485
# [Epoch 6, Batch 1000] loss: 0.563
# [Epoch 6, Batch 1100] loss: 0.534
# [Epoch 6, Batch 1200] loss: 0.548
# [Epoch 6, Batch 1300] loss: 0.541
# [Epoch 6, Batch 1400] loss: 0.549
# [Epoch 6, Batch 1500] loss: 0.522
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82      1000
#            1       0.89      0.85      0.87      1000
#            2       0.80      0.77      0.79      1000
#            3       0.71      0.69      0.70      1000
#            4       0.78      0.78      0.78      1000
#            5       0.79      0.77      0.78      1000
#            6       0.84      0.86      0.85      1000
#            7       0.85      0.80      0.82      1000
#            8       0.86      0.87      0.87      1000
#            9       0.83      0.88      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 7, Batch 100] loss: 0.485
# [Epoch 7, Batch 200] loss: 0.504
# [Epoch 7, Batch 300] loss: 0.490
# [Epoch 7, Batch 400] loss: 0.540
# [Epoch 7, Batch 500] loss: 0.492
# [Epoch 7, Batch 600] loss: 0.500
# [Epoch 7, Batch 700] loss: 0.483
# [Epoch 7, Batch 800] loss: 0.498
# [Epoch 7, Batch 900] loss: 0.488
# [Epoch 7, Batch 1000] loss: 0.483
# [Epoch 7, Batch 1100] loss: 0.497
# [Epoch 7, Batch 1200] loss: 0.504
# [Epoch 7, Batch 1300] loss: 0.508
# [Epoch 7, Batch 1400] loss: 0.493
# [Epoch 7, Batch 1500] loss: 0.484
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82      1000
#            1       0.89      0.88      0.88      1000
#            2       0.80      0.78      0.79      1000
#            3       0.73      0.65      0.69      1000
#            4       0.78      0.78      0.78      1000
#            5       0.74      0.81      0.77      1000
#            6       0.85      0.86      0.85      1000
#            7       0.83      0.83      0.83      1000
#            8       0.84      0.90      0.87      1000
#            9       0.83      0.89      0.86      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.81     10000
# weighted avg       0.82      0.82      0.81     10000
#
# [Epoch 8, Batch 100] loss: 0.464
# [Epoch 8, Batch 200] loss: 0.451
# [Epoch 8, Batch 300] loss: 0.442
# [Epoch 8, Batch 400] loss: 0.463
# [Epoch 8, Batch 500] loss: 0.433
# [Epoch 8, Batch 600] loss: 0.483
# [Epoch 8, Batch 700] loss: 0.476
# [Epoch 8, Batch 800] loss: 0.466
# [Epoch 8, Batch 900] loss: 0.455
# [Epoch 8, Batch 1000] loss: 0.495
# [Epoch 8, Batch 1100] loss: 0.464
# [Epoch 8, Batch 1200] loss: 0.466
# [Epoch 8, Batch 1300] loss: 0.488
# [Epoch 8, Batch 1400] loss: 0.498
# [Epoch 8, Batch 1500] loss: 0.464
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1000
#            1       0.92      0.86      0.89      1000
#            2       0.83      0.72      0.77      1000
#            3       0.71      0.68      0.70      1000
#            4       0.77      0.77      0.77      1000
#            5       0.81      0.73      0.77      1000
#            6       0.79      0.90      0.84      1000
#            7       0.78      0.87      0.82      1000
#            8       0.89      0.87      0.88      1000
#            9       0.84      0.89      0.87      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# [Epoch 9, Batch 100] loss: 0.444
# [Epoch 9, Batch 200] loss: 0.434
# [Epoch 9, Batch 300] loss: 0.424
# [Epoch 9, Batch 400] loss: 0.410
# [Epoch 9, Batch 500] loss: 0.414
# [Epoch 9, Batch 600] loss: 0.443
# [Epoch 9, Batch 700] loss: 0.428
# [Epoch 9, Batch 800] loss: 0.446
# [Epoch 9, Batch 900] loss: 0.421
# [Epoch 9, Batch 1000] loss: 0.481
# [Epoch 9, Batch 1100] loss: 0.426
# [Epoch 9, Batch 1200] loss: 0.465
# [Epoch 9, Batch 1300] loss: 0.436
# [Epoch 9, Batch 1400] loss: 0.430
# [Epoch 9, Batch 1500] loss: 0.449
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84      1000
#            1       0.84      0.91      0.88      1000
#            2       0.83      0.77      0.80      1000
#            3       0.69      0.66      0.68      1000
#            4       0.78      0.79      0.78      1000
#            5       0.78      0.77      0.77      1000
#            6       0.83      0.86      0.85      1000
#            7       0.83      0.85      0.84      1000
#            8       0.86      0.88      0.87      1000
#            9       0.90      0.86      0.88      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000
#
# [Epoch 10, Batch 100] loss: 0.350
# [Epoch 10, Batch 200] loss: 0.406
# [Epoch 10, Batch 300] loss: 0.403
# [Epoch 10, Batch 400] loss: 0.423
# [Epoch 10, Batch 500] loss: 0.391
# [Epoch 10, Batch 600] loss: 0.407
# [Epoch 10, Batch 700] loss: 0.447
# [Epoch 10, Batch 800] loss: 0.403
# [Epoch 10, Batch 900] loss: 0.391
# [Epoch 10, Batch 1000] loss: 0.415
# [Epoch 10, Batch 1100] loss: 0.437
# [Epoch 10, Batch 1200] loss: 0.414
# [Epoch 10, Batch 1300] loss: 0.411
# [Epoch 10, Batch 1400] loss: 0.424
# [Epoch 10, Batch 1500] loss: 0.399
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1000
#            1       0.88      0.87      0.88      1000
#            2       0.81      0.76      0.78      1000
#            3       0.65      0.73      0.69      1000
#            4       0.79      0.75      0.77      1000
#            5       0.79      0.74      0.77      1000
#            6       0.83      0.87      0.85      1000
#            7       0.82      0.83      0.82      1000
#            8       0.88      0.85      0.86      1000
#            9       0.85      0.86      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# Finished Training

# %%
from torchvision import models
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn, optim
from torchvision.models import resnet18
import torch.nn.functional as F
from pytorch_lightning import seed_everything
import random
from sklearn.metrics import classification_report


hidden_features = 512
seed_everything(1)
one_dimentional_data = False

# Step 1: Define the transformations for the training and test sets
transform = transforms.Compose([
    transforms.Grayscale(3) if one_dimentional_data else transforms.Lambda(lambda x: x),
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])


# Step 2: Load CIFAR-10 dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)


# Step 4: Initialize ResNet-18 model and modify it
class ResNet18(nn.Module):
    def __init__(self, num_anchors, hidden_features, fine_tune=False):
        super(ResNet18, self).__init__()
        # Remove the last fully connected layer
        self.resnet = resnet18(pretrained=True)
        self.resnet18_fc_shape = self.resnet.fc.in_features
        self.resnet.fc = nn.Identity()
        
        if not fine_tune:
            for param in self.resnet.parameters():
                param.requires_grad = False
                param.grad = None
            
        self.output_layer = nn.Linear(in_features=hidden_features, out_features=10)
        self.post_resnet_nn = nn.Sequential(
            nn.Linear(in_features=self.resnet18_fc_shape, out_features=self.resnet18_fc_shape),
            nn.BatchNorm1d(num_features=self.resnet18_fc_shape),
            nn.Tanh(),
            nn.Linear(in_features=self.resnet18_fc_shape, out_features=hidden_features),
            nn.Tanh(),
        )

    def forward(self, x):
        with torch.no_grad():
            x_latents = self.resnet(x)
        x_latents = self.post_resnet_nn(x_latents)
        return self.output_layer(x_latents)


# Initialize the modified model
model = ResNet18(hidden_features=hidden_features, num_anchors=num_anchors)

# If using a GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Step 5: Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Step 6: Train the model
def train(epoch):
    model.train()
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i % 100 == 99:    # print every 100 mini-batches
            print(f'[Epoch {epoch + 1}, Batch {i + 1}] loss: {running_loss / 100:.3f}')
            running_loss = 0.0

# Step 7: Evaluate the model
def test():
    model.eval()
    all_labels = []
    all_predictions = []
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    print(classification_report(all_labels, all_predictions))

# Training and Testing Loop
for epoch in range(10):  # number of epochs
    train(epoch)
    test()

print('Finished Training')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [Epoch 1, Batch 100] loss: 0.945
# [Epoch 1, Batch 200] loss: 0.776
# [Epoch 1, Batch 300] loss: 0.769
# [Epoch 1, Batch 400] loss: 0.742
# [Epoch 1, Batch 500] loss: 0.737
# [Epoch 1, Batch 600] loss: 0.694
# [Epoch 1, Batch 700] loss: 0.714
# [Epoch 1, Batch 800] loss: 0.701
# [Epoch 1, Batch 900] loss: 0.693
# [Epoch 1, Batch 1000] loss: 0.693
# [Epoch 1, Batch 1100] loss: 0.732
# [Epoch 1, Batch 1200] loss: 0.709
# [Epoch 1, Batch 1300] loss: 0.649
# [Epoch 1, Batch 1400] loss: 0.657
# [Epoch 1, Batch 1500] loss: 0.677
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80      1000
#            1       0.91      0.84      0.87      1000
#            2       0.79      0.58      0.67      1000
#            3       0.61      0.71      0.66      1000
#            4       0.82      0.67      0.74      1000
#            5       0.72      0.75      0.74      1000
#            6       0.73      0.91      0.81      1000
#            7       0.79      0.80      0.80      1000
#            8       0.86      0.83      0.85      1000
#            9       0.83      0.88      0.85      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.78     10000
# weighted avg       0.78      0.78      0.78     10000
#
# [Epoch 2, Batch 100] loss: 0.659
# [Epoch 2, Batch 200] loss: 0.609
# [Epoch 2, Batch 300] loss: 0.612
# [Epoch 2, Batch 400] loss: 0.654
# [Epoch 2, Batch 500] loss: 0.629
# [Epoch 2, Batch 600] loss: 0.634
# [Epoch 2, Batch 700] loss: 0.639
# [Epoch 2, Batch 800] loss: 0.656
# [Epoch 2, Batch 900] loss: 0.677
# [Epoch 2, Batch 1000] loss: 0.639
# [Epoch 2, Batch 1100] loss: 0.645
# [Epoch 2, Batch 1200] loss: 0.639
# [Epoch 2, Batch 1300] loss: 0.606
# [Epoch 2, Batch 1400] loss: 0.631
# [Epoch 2, Batch 1500] loss: 0.643
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81      1000
#            1       0.88      0.88      0.88      1000
#            2       0.76      0.75      0.75      1000
#            3       0.62      0.77      0.68      1000
#            4       0.76      0.76      0.76      1000
#            5       0.86      0.62      0.72      1000
#            6       0.81      0.86      0.83      1000
#            7       0.82      0.80      0.81      1000
#            8       0.89      0.83      0.86      1000
#            9       0.86      0.86      0.86      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.80      0.80     10000
#
# [Epoch 3, Batch 100] loss: 0.595
# [Epoch 3, Batch 200] loss: 0.584
# [Epoch 3, Batch 300] loss: 0.612
# [Epoch 3, Batch 400] loss: 0.617
# [Epoch 3, Batch 500] loss: 0.569
# [Epoch 3, Batch 600] loss: 0.589
# [Epoch 3, Batch 700] loss: 0.602
# [Epoch 3, Batch 800] loss: 0.587
# [Epoch 3, Batch 900] loss: 0.601
# [Epoch 3, Batch 1000] loss: 0.595
# [Epoch 3, Batch 1100] loss: 0.618
# [Epoch 3, Batch 1200] loss: 0.599
# [Epoch 3, Batch 1300] loss: 0.620
# [Epoch 3, Batch 1400] loss: 0.594
# [Epoch 3, Batch 1500] loss: 0.580
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80      1000
#            1       0.86      0.87      0.87      1000
#            2       0.82      0.71      0.76      1000
#            3       0.71      0.63      0.67      1000
#            4       0.72      0.80      0.76      1000
#            5       0.71      0.84      0.77      1000
#            6       0.83      0.83      0.83      1000
#            7       0.86      0.75      0.80      1000
#            8       0.85      0.88      0.86      1000
#            9       0.88      0.82      0.85      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.80      0.80     10000
#
# [Epoch 4, Batch 100] loss: 0.539
# [Epoch 4, Batch 200] loss: 0.564
# [Epoch 4, Batch 300] loss: 0.557
# [Epoch 4, Batch 400] loss: 0.574
# [Epoch 4, Batch 500] loss: 0.571
# [Epoch 4, Batch 600] loss: 0.558
# [Epoch 4, Batch 700] loss: 0.573
# [Epoch 4, Batch 800] loss: 0.560
# [Epoch 4, Batch 900] loss: 0.553
# [Epoch 4, Batch 1000] loss: 0.599
# [Epoch 4, Batch 1100] loss: 0.572
# [Epoch 4, Batch 1200] loss: 0.585
# [Epoch 4, Batch 1300] loss: 0.566
# [Epoch 4, Batch 1400] loss: 0.552
# [Epoch 4, Batch 1500] loss: 0.582
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82      1000
#            1       0.94      0.80      0.87      1000
#            2       0.72      0.80      0.76      1000
#            3       0.65      0.72      0.69      1000
#            4       0.81      0.76      0.78      1000
#            5       0.80      0.69      0.74      1000
#            6       0.86      0.85      0.85      1000
#            7       0.80      0.83      0.82      1000
#            8       0.82      0.91      0.86      1000
#            9       0.87      0.86      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 5, Batch 100] loss: 0.512
# [Epoch 5, Batch 200] loss: 0.543
# [Epoch 5, Batch 300] loss: 0.532
# [Epoch 5, Batch 400] loss: 0.494
# [Epoch 5, Batch 500] loss: 0.520
# [Epoch 5, Batch 600] loss: 0.550
# [Epoch 5, Batch 700] loss: 0.504
# [Epoch 5, Batch 800] loss: 0.544
# [Epoch 5, Batch 900] loss: 0.560
# [Epoch 5, Batch 1000] loss: 0.513
# [Epoch 5, Batch 1100] loss: 0.537
# [Epoch 5, Batch 1200] loss: 0.530
# [Epoch 5, Batch 1300] loss: 0.537
# [Epoch 5, Batch 1400] loss: 0.572
# [Epoch 5, Batch 1500] loss: 0.571
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1000
#            1       0.89      0.87      0.88      1000
#            2       0.83      0.73      0.78      1000
#            3       0.66      0.75      0.70      1000
#            4       0.79      0.73      0.76      1000
#            5       0.79      0.74      0.77      1000
#            6       0.86      0.85      0.85      1000
#            7       0.80      0.85      0.83      1000
#            8       0.83      0.90      0.86      1000
#            9       0.87      0.86      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 6, Batch 100] loss: 0.481
# [Epoch 6, Batch 200] loss: 0.492
# [Epoch 6, Batch 300] loss: 0.481
# [Epoch 6, Batch 400] loss: 0.497
# [Epoch 6, Batch 500] loss: 0.507
# [Epoch 6, Batch 600] loss: 0.512
# [Epoch 6, Batch 700] loss: 0.502
# [Epoch 6, Batch 800] loss: 0.517
# [Epoch 6, Batch 900] loss: 0.502
# [Epoch 6, Batch 1000] loss: 0.506
# [Epoch 6, Batch 1100] loss: 0.518
# [Epoch 6, Batch 1200] loss: 0.518
# [Epoch 6, Batch 1300] loss: 0.538
# [Epoch 6, Batch 1400] loss: 0.513
# [Epoch 6, Batch 1500] loss: 0.519
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      1000
#            1       0.89      0.90      0.89      1000
#            2       0.75      0.80      0.77      1000
#            3       0.62      0.76      0.68      1000
#            4       0.81      0.73      0.77      1000
#            5       0.78      0.71      0.75      1000
#            6       0.82      0.82      0.82      1000
#            7       0.86      0.81      0.83      1000
#            8       0.90      0.83      0.87      1000
#            9       0.88      0.86      0.87      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 7, Batch 100] loss: 0.462
# [Epoch 7, Batch 200] loss: 0.464
# [Epoch 7, Batch 300] loss: 0.448
# [Epoch 7, Batch 400] loss: 0.472
# [Epoch 7, Batch 500] loss: 0.444
# [Epoch 7, Batch 600] loss: 0.475
# [Epoch 7, Batch 700] loss: 0.491
# [Epoch 7, Batch 800] loss: 0.477
# [Epoch 7, Batch 900] loss: 0.470
# [Epoch 7, Batch 1000] loss: 0.463
# [Epoch 7, Batch 1100] loss: 0.503
# [Epoch 7, Batch 1200] loss: 0.500
# [Epoch 7, Batch 1300] loss: 0.501
# [Epoch 7, Batch 1400] loss: 0.481
# [Epoch 7, Batch 1500] loss: 0.466
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84      1000
#            1       0.89      0.86      0.88      1000
#            2       0.80      0.77      0.78      1000
#            3       0.69      0.69      0.69      1000
#            4       0.78      0.75      0.76      1000
#            5       0.76      0.77      0.77      1000
#            6       0.78      0.89      0.83      1000
#            7       0.85      0.82      0.83      1000
#            8       0.86      0.88      0.87      1000
#            9       0.86      0.86      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 8, Batch 100] loss: 0.428
# [Epoch 8, Batch 200] loss: 0.409
# [Epoch 8, Batch 300] loss: 0.419
# [Epoch 8, Batch 400] loss: 0.449
# [Epoch 8, Batch 500] loss: 0.438
# [Epoch 8, Batch 600] loss: 0.478
# [Epoch 8, Batch 700] loss: 0.451
# [Epoch 8, Batch 800] loss: 0.473
# [Epoch 8, Batch 900] loss: 0.412
# [Epoch 8, Batch 1000] loss: 0.462
# [Epoch 8, Batch 1100] loss: 0.455
# [Epoch 8, Batch 1200] loss: 0.462
# [Epoch 8, Batch 1300] loss: 0.446
# [Epoch 8, Batch 1400] loss: 0.465
# [Epoch 8, Batch 1500] loss: 0.442
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84      1000
#            1       0.88      0.88      0.88      1000
#            2       0.79      0.79      0.79      1000
#            3       0.66      0.69      0.68      1000
#            4       0.75      0.80      0.77      1000
#            5       0.76      0.78      0.77      1000
#            6       0.85      0.83      0.84      1000
#            7       0.87      0.80      0.83      1000
#            8       0.86      0.88      0.87      1000
#            9       0.87      0.87      0.87      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 9, Batch 100] loss: 0.408
# [Epoch 9, Batch 200] loss: 0.384
# [Epoch 9, Batch 300] loss: 0.407
# [Epoch 9, Batch 400] loss: 0.390
# [Epoch 9, Batch 500] loss: 0.410
# [Epoch 9, Batch 600] loss: 0.398
# [Epoch 9, Batch 700] loss: 0.415
# [Epoch 9, Batch 800] loss: 0.421
# [Epoch 9, Batch 900] loss: 0.426
# [Epoch 9, Batch 1000] loss: 0.409
# [Epoch 9, Batch 1100] loss: 0.433
# [Epoch 9, Batch 1200] loss: 0.427
# [Epoch 9, Batch 1300] loss: 0.413
# [Epoch 9, Batch 1400] loss: 0.437
# [Epoch 9, Batch 1500] loss: 0.464
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83      1000
#            1       0.85      0.91      0.88      1000
#            2       0.80      0.76      0.78      1000
#            3       0.69      0.64      0.66      1000
#            4       0.77      0.79      0.78      1000
#            5       0.72      0.81      0.76      1000
#            6       0.83      0.85      0.84      1000
#            7       0.86      0.81      0.83      1000
#            8       0.88      0.86      0.87      1000
#            9       0.91      0.83      0.87      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# [Epoch 10, Batch 100] loss: 0.352
# [Epoch 10, Batch 200] loss: 0.367
# [Epoch 10, Batch 300] loss: 0.377
# [Epoch 10, Batch 400] loss: 0.375
# [Epoch 10, Batch 500] loss: 0.367
# [Epoch 10, Batch 600] loss: 0.380
# [Epoch 10, Batch 700] loss: 0.365
# [Epoch 10, Batch 800] loss: 0.371
# [Epoch 10, Batch 900] loss: 0.407
# [Epoch 10, Batch 1000] loss: 0.412
# [Epoch 10, Batch 1100] loss: 0.432
# [Epoch 10, Batch 1200] loss: 0.420
# [Epoch 10, Batch 1300] loss: 0.391
# [Epoch 10, Batch 1400] loss: 0.395
# [Epoch 10, Batch 1500] loss: 0.394
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84      1000
#            1       0.89      0.87      0.88      1000
#            2       0.79      0.76      0.78      1000
#            3       0.70      0.66      0.68      1000
#            4       0.74      0.80      0.77      1000
#            5       0.78      0.73      0.75      1000
#            6       0.80      0.88      0.83      1000
#            7       0.82      0.80      0.81      1000
#            8       0.86      0.89      0.88      1000
#            9       0.87      0.88      0.88      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# Finished Training
